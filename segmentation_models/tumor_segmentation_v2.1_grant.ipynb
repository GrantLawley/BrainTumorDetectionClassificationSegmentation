# %%
import sys
sys.path.append("..")  # needed to import dataloader.py

import torch
import torchvision
from dataloader import MultiTaskBrainDataset
from torch.utils.data import DataLoader
from torchinfo import summary
torch.manual_seed(42)  # set seed for reproducibility

device = torch.device("cpu")

# %%
class ConvBlock(torch.nn.Module):
    """Two conv layers with GN + ReLU."""
    def __init__(self, in_ch, out_ch):
        super().__init__()
        self.block = torch.nn.Sequential(
            torch.nn.Conv2d(in_ch, out_ch, kernel_size=3, padding=1, bias=False),
            torch.nn.GroupNorm(4, out_ch),
            torch.nn.ReLU(inplace=True),
            torch.nn.Conv2d(out_ch, out_ch, kernel_size=3, padding=1, bias=False),
            torch.nn.GroupNorm(4, out_ch),
            torch.nn.ReLU(inplace=True),
        )
    def forward(self, x):
        return self.block(x)


class TinyUNet(torch.nn.Module):
    """
    Lightweight U-Net for CPU inference.

    Encoder: 3 levels
    Skip connections preserved for segmentation quality.

    Input:  (B, 1, H, W)
    Output: (B, num_classes, H, W) - raw logits
    """
    def __init__(self, num_classes=1, base_ch=12):
        super().__init__()

        
        self.enc1 = ConvBlock(1,         base_ch)      
        self.enc2 = ConvBlock(base_ch,   base_ch*2)    
        self.enc3 = ConvBlock(base_ch*2, base_ch*4)   
        self.pool = torch.nn.MaxPool2d(2)

        
        self.bottleneck = ConvBlock(base_ch*4, base_ch*8)

        
        self.up3  = torch.nn.ConvTranspose2d(base_ch*8, base_ch*4, kernel_size=2, stride=2)
        self.dec3 = ConvBlock(base_ch*8, base_ch*4)   

        self.up2  = torch.nn.ConvTranspose2d(base_ch*4, base_ch*2, kernel_size=2, stride=2)
        self.dec2 = ConvBlock(base_ch*4, base_ch*2)   

        self.up1  = torch.nn.ConvTranspose2d(base_ch*2, base_ch,   kernel_size=2, stride=2)
        self.dec1 = ConvBlock(base_ch*2, base_ch)  

        
        self.head = torch.nn.Conv2d(base_ch, num_classes, kernel_size=1)

    def forward(self, x):
        s1 = self.enc1(x)
        s2 = self.enc2(self.pool(s1))
        s3 = self.enc3(self.pool(s2))

        x = self.bottleneck(self.pool(s3))

        x = self.dec3(torch.cat([self.up3(x), s3], dim=1))
        x = self.dec2(torch.cat([self.up2(x), s2], dim=1))
        x = self.dec1(torch.cat([self.up1(x), s1], dim=1))

        return self.head(x)
    
class DiceBCELoss(torch.nn.Module):
    def __init__(self, bce_weight=0.5, dice_weight=0.5, eps=1e-6, pos_weight=10.0):
        super().__init__()
        self.bce_weight  = bce_weight
        self.dice_weight = dice_weight
        self.eps         = eps
        self.pos_weight  = pos_weight

    def forward(self, pred_logits, target):
        probs = torch.sigmoid(pred_logits)

        # Weighted BCE
        bce = -(target * torch.log(probs + 1e-6) * self.pos_weight +
                (1 - target) * torch.log(1 - probs + 1e-6))
        bce_loss = bce.mean()

        # Dice
        intersection = (probs * target).sum(dim=(1,2,3))
        union        = probs.sum(dim=(1,2,3)) + target.sum(dim=(1,2,3))
        dice_loss    = 1 - (2*intersection + self.eps) / (union + self.eps)
        dice_loss    = dice_loss.mean()

        return self.bce_weight * bce_loss + self.dice_weight * dice_loss

# %%
model = TinyUNet(num_classes=1, base_ch=12)
model.to(device)
print(summary(model, input_size=(4, 1, 256, 256)))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# TinyUNet                                 [4, 1, 256, 256]          --
# ├─ConvBlock: 1-1                         [4, 12, 256, 256]         --
# │    └─Sequential: 2-1                   [4, 12, 256, 256]         --
# │    │    └─Conv2d: 3-1                  [4, 12, 256, 256]         108
# │    │    └─GroupNorm: 3-2               [4, 12, 256, 256]         24
# │    │    └─ReLU: 3-3                    [4, 12, 256, 256]         --
# │    │    └─Conv2d: 3-4                  [4, 12, 256, 256]         1,296
# │    │    └─GroupNorm: 3-5               [4, 12, 256, 256]         24
# │    │    └─ReLU: 3-6                    [4, 12, 256, 256]         --
# ├─MaxPool2d: 1-2                         [4, 12, 128, 128]         --
# ├─ConvBlock: 1-3                         [4, 24, 128, 128]         --
# │    └─Sequential: 2-2                   [4, 24, 128, 128]         --
# │    │    └─Conv2d: 3-7                  [4, 24, 128, 128]         2,592
# │    │    └─GroupNorm: 3-8               [4, 24, 128, 128]         48
# │    │    └─ReLU: 3-9                    [4, 24, 128, 128]         --
# │    │    └─Conv2d: 3-10                 [4, 24, 128, 128]         5,184
# │    │    └─GroupNorm: 3-11              [4, 24, 128, 128]         48
# │    │    └─ReLU: 3-12                   [4, 24, 128, 128]         --
# ├─MaxPool2d: 1-4                         [4, 24, 64, 64]           --
# ├─ConvBlock: 1-5                         [4, 48, 64, 64]           --
# │    └─Sequential: 2-3                   [4, 48, 64, 64]           --
# │    │    └─Conv2d: 3-13                 [4, 48, 64, 64]           10,368
# │    │    └─GroupNorm: 3-14              [4, 48, 64, 64]           96
# │    │    └─ReLU: 3-15                   [4, 48, 64, 64]           --
# │    │    └─Conv2d: 3-16                 [4, 48, 64, 64]           20,736
# │    │    └─GroupNorm: 3-17              [4, 48, 64, 64]           96
# │    │    └─ReLU: 3-18                   [4, 48, 64, 64]           --
# ├─MaxPool2d: 1-6                         [4, 48, 32, 32]           --
# ├─ConvBlock: 1-7                         [4, 96, 32, 32]           --
# │    └─Sequential: 2-4                   [4, 96, 32, 32]           --
# │    │    └─Conv2d: 3-19                 [4, 96, 32, 32]           41,472
# │    │    └─GroupNorm: 3-20              [4, 96, 32, 32]           192
# │    │    └─ReLU: 3-21                   [4, 96, 32, 32]           --
# │    │    └─Conv2d: 3-22                 [4, 96, 32, 32]           82,944
# │    │    └─GroupNorm: 3-23              [4, 96, 32, 32]           192
# │    │    └─ReLU: 3-24                   [4, 96, 32, 32]           --
# ├─ConvTranspose2d: 1-8                   [4, 48, 64, 64]           18,480
# ├─ConvBlock: 1-9                         [4, 48, 64, 64]           --
# │    └─Sequential: 2-5                   [4, 48, 64, 64]           --
# │    │    └─Conv2d: 3-25                 [4, 48, 64, 64]           41,472
# │    │    └─GroupNorm: 3-26              [4, 48, 64, 64]           96
# │    │    └─ReLU: 3-27                   [4, 48, 64, 64]           --
# │    │    └─Conv2d: 3-28                 [4, 48, 64, 64]           20,736
# │    │    └─GroupNorm: 3-29              [4, 48, 64, 64]           96
# │    │    └─ReLU: 3-30                   [4, 48, 64, 64]           --
# ├─ConvTranspose2d: 1-10                  [4, 24, 128, 128]         4,632
# ├─ConvBlock: 1-11                        [4, 24, 128, 128]         --
# │    └─Sequential: 2-6                   [4, 24, 128, 128]         --
# │    │    └─Conv2d: 3-31                 [4, 24, 128, 128]         10,368
# │    │    └─GroupNorm: 3-32              [4, 24, 128, 128]         48
# │    │    └─ReLU: 3-33                   [4, 24, 128, 128]         --
# │    │    └─Conv2d: 3-34                 [4, 24, 128, 128]         5,184
# │    │    └─GroupNorm: 3-35              [4, 24, 128, 128]         48
# │    │    └─ReLU: 3-36                   [4, 24, 128, 128]         --
# ├─ConvTranspose2d: 1-12                  [4, 12, 256, 256]         1,164
# ├─ConvBlock: 1-13                        [4, 12, 256, 256]         --
# │    └─Sequential: 2-7                   [4, 12, 256, 256]         --
# │    │    └─Conv2d: 3-37                 [4, 12, 256, 256]         2,592
# │    │    └─GroupNorm: 3-38              [4, 12, 256, 256]         24
# │    │    └─ReLU: 3-39                   [4, 12, 256, 256]         --
# │    │    └─Conv2d: 3-40                 [4, 12, 256, 256]         1,296
# │    │    └─GroupNorm: 3-41              [4, 12, 256, 256]         24
# │    │    └─ReLU: 3-42                   [4, 12, 256, 256]         --
# ├─Conv2d: 1-14                           [4, 1, 256, 256]          13
# ==========================================================================================
# Total params: 271,693
# Trainable params: 271,693
# Non-trainable params: 0
# Total mult-adds (G): 5.87
# ==========================================================================================
# Input size (MB): 1.05
# Forward/backward pass size (MB): 411.04
# Params size (MB): 1.09
# Estimated Total Size (MB): 413.18
# ==========================================================================================

# %%
from torch.utils.data import DataLoader
import os
import json

train_data = MultiTaskBrainDataset(
    os.path.join("..", "brisc2025"),
    mode="segmentation",
    train_or_test="train",
    subset="train",
    augment=True,
    seed=42,
    new_height=256, 
    new_width=256
)

val_data = MultiTaskBrainDataset(
    os.path.join("..", "brisc2025"),
    mode="segmentation",
    train_or_test="train",
    subset="val",
    augment=False,
    seed=42,
    new_height=256, 
    new_width=256
)

train_loader = DataLoader(train_data, batch_size=6, shuffle=True,  num_workers=0)
val_loader   = DataLoader(val_data,   batch_size=6, shuffle=False, num_workers=0)

loss_fn   = DiceBCELoss(bce_weight=0.5, dice_weight=0.5)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3)

def dice_coefficient(pred_logits, target, threshold=0.5, eps=1e-6):
    """
    Computes the Dice score between predicted binary mask and ground truth.
    pred_logits: raw model output (B, 1, H, W)
    target:      ground truth mask (B, 1, H, W), values in {0, 1}
    """
    probs = torch.sigmoid(pred_logits)
    preds = (probs > threshold).float()
    intersection = (preds * target).sum(dim=(1, 2, 3))
    union = preds.sum(dim=(1, 2, 3)) + target.sum(dim=(1, 2, 3))
    dice = (2.0 * intersection + eps) / (union + eps)
    return dice.mean().item()

best_val_dice  = 0.0
checkpoint_dir = os.path.join("..", "results", "segmentation", "tumor_segmentation_v2.1_grant")
os.makedirs(checkpoint_dir, exist_ok=True)

best_model_path = os.path.join(checkpoint_dir, "best_model.pt")
metadata_path   = os.path.join(checkpoint_dir, "training_metadata.json")

training_metadata = {
    "best_val_dice": 0.0,
    "best_epoch":    None,
    "history":       []
}

for epoch in range(100):
    model.train()
    running_loss = 0.0
    running_dice = 0.0

    for inputs, masks in train_loader:
        inputs, masks = inputs.to(device), masks.float().to(device)

        optimizer.zero_grad()
        predictions = model(inputs)
        loss = loss_fn(predictions, masks)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        running_dice += dice_coefficient(predictions, masks)

    epoch_loss = running_loss / len(train_loader)
    epoch_dice = running_dice / len(train_loader)

    # Validation
    model.eval()
    val_loss = 0.0
    val_dice = 0.0

    with torch.no_grad():
        for inputs, masks in val_loader:
            inputs, masks = inputs.to(device), masks.float().to(device)
            predictions = model(inputs)
            loss = loss_fn(predictions, masks.float())
            val_loss += loss.item()
            val_dice += dice_coefficient(predictions, masks)

    val_loss /= len(val_loader)
    val_dice /= len(val_loader)

    print(
        f"Epoch {epoch+1:03d} | "
        f"Train Loss: {epoch_loss:.4f} | Train Dice: {epoch_dice:.4f} | "
        f"Val Loss: {val_loss:.4f} | Val Dice: {val_dice:.4f}"
    )

    # Record epoch metrics in metadata
    training_metadata["history"].append({
        "epoch":      epoch + 1,
        "train_loss": round(epoch_loss, 6),
        "train_dice": round(epoch_dice, 6),
        "val_loss":   round(val_loss,   6),
        "val_dice":   round(val_dice,   6),
    })

    # Save best model and update metadata if improved
    if val_dice > best_val_dice:
        best_val_dice = val_dice
        training_metadata["best_val_dice"] = round(val_dice, 6)
        training_metadata["best_epoch"]    = epoch + 1

        torch.save({
            "epoch":                epoch + 1,
            "model_state_dict":     model.state_dict(),
            "optimizer_state_dict": optimizer.state_dict(),
            "val_dice":             val_dice,
            "val_loss":             val_loss,
        }, best_model_path)
        print(f"  -> Best model saved (epoch {epoch+1}, val_dice={val_dice:.4f})")

    # Write metadata JSON after every epoch
    with open(metadata_path, "w") as f:
        json.dump(training_metadata, f, indent=4)
# Out:
# Epoch 001 | Train Loss: 0.5937 | Train Dice: 0.2194 | Val Loss: 0.5290 | Val Dice: 0.3266
#   -> Best model saved (epoch 1, val_dice=0.3266)
# Epoch 002 | Train Loss: 0.5095 | Train Dice: 0.3394 | Val Loss: 0.4626 | Val Dice: 0.3984
#   -> Best model saved (epoch 2, val_dice=0.3984)
# Epoch 003 | Train Loss: 0.4469 | Train Dice: 0.4299 | Val Loss: 0.4124 | Val Dice: 0.4389
#   -> Best model saved (epoch 3, val_dice=0.4389)
# Epoch 004 | Train Loss: 0.3782 | Train Dice: 0.4857 | Val Loss: 0.3285 | Val Dice: 0.5198
#   -> Best model saved (epoch 4, val_dice=0.5198)
# Epoch 005 | Train Loss: 0.3362 | Train Dice: 0.5177 | Val Loss: 0.2897 | Val Dice: 0.5669
#   -> Best model saved (epoch 5, val_dice=0.5669)
# Epoch 006 | Train Loss: 0.3153 | Train Dice: 0.5485 | Val Loss: 0.2889 | Val Dice: 0.5603
# Epoch 007 | Train Loss: 0.3037 | Train Dice: 0.5693 | Val Loss: 0.2868 | Val Dice: 0.5688
#   -> Best model saved (epoch 7, val_dice=0.5688)
# Epoch 008 | Train Loss: 0.2885 | Train Dice: 0.5899 | Val Loss: 0.2703 | Val Dice: 0.6244
#   -> Best model saved (epoch 8, val_dice=0.6244)
# Epoch 009 | Train Loss: 0.2872 | Train Dice: 0.5916 | Val Loss: 0.2588 | Val Dice: 0.6350
#   -> Best model saved (epoch 9, val_dice=0.6350)
# Epoch 010 | Train Loss: 0.2756 | Train Dice: 0.6117 | Val Loss: 0.2669 | Val Dice: 0.6297
# Epoch 011 | Train Loss: 0.2712 | Train Dice: 0.6230 | Val Loss: 0.2420 | Val Dice: 0.6419
#   -> Best model saved (epoch 11, val_dice=0.6419)
# Epoch 012 | Train Loss: 0.2672 | Train Dice: 0.6253 | Val Loss: 0.2624 | Val Dice: 0.6124
# Epoch 013 | Train Loss: 0.2633 | Train Dice: 0.6394 | Val Loss: 0.2550 | Val Dice: 0.6044
# Epoch 014 | Train Loss: 0.2609 | Train Dice: 0.6419 | Val Loss: 0.2416 | Val Dice: 0.7149
#   -> Best model saved (epoch 14, val_dice=0.7149)
# Epoch 015 | Train Loss: 0.2573 | Train Dice: 0.6452 | Val Loss: 0.2434 | Val Dice: 0.6419
# Epoch 016 | Train Loss: 0.2508 | Train Dice: 0.6546 | Val Loss: 0.2496 | Val Dice: 0.6339
# Epoch 017 | Train Loss: 0.2525 | Train Dice: 0.6649 | Val Loss: 0.2291 | Val Dice: 0.7172
#   -> Best model saved (epoch 17, val_dice=0.7172)
# Epoch 018 | Train Loss: 0.2512 | Train Dice: 0.6561 | Val Loss: 0.2387 | Val Dice: 0.6598
# Epoch 019 | Train Loss: 0.2456 | Train Dice: 0.6688 | Val Loss: 0.2702 | Val Dice: 0.5784
# Epoch 020 | Train Loss: 0.2452 | Train Dice: 0.6838 | Val Loss: 0.2256 | Val Dice: 0.7436
#   -> Best model saved (epoch 20, val_dice=0.7436)
# Epoch 021 | Train Loss: 0.2398 | Train Dice: 0.6824 | Val Loss: 0.2309 | Val Dice: 0.6580
# Epoch 022 | Train Loss: 0.2404 | Train Dice: 0.6892 | Val Loss: 0.2239 | Val Dice: 0.7607
#   -> Best model saved (epoch 22, val_dice=0.7607)
# Epoch 023 | Train Loss: 0.2386 | Train Dice: 0.6809 | Val Loss: 0.2369 | Val Dice: 0.6850
# Epoch 024 | Train Loss: 0.2392 | Train Dice: 0.6914 | Val Loss: 0.2354 | Val Dice: 0.6871
# Epoch 025 | Train Loss: 0.2391 | Train Dice: 0.6955 | Val Loss: 0.2292 | Val Dice: 0.7435
# Epoch 026 | Train Loss: 0.2368 | Train Dice: 0.6906 | Val Loss: 0.2332 | Val Dice: 0.6822
# Epoch 027 | Train Loss: 0.2327 | Train Dice: 0.6979 | Val Loss: 0.2290 | Val Dice: 0.6966
# Epoch 028 | Train Loss: 0.2275 | Train Dice: 0.7130 | Val Loss: 0.2331 | Val Dice: 0.6390
# Epoch 029 | Train Loss: 0.2293 | Train Dice: 0.6964 | Val Loss: 0.2246 | Val Dice: 0.7136
# Epoch 030 | Train Loss: 0.2304 | Train Dice: 0.7015 | Val Loss: 0.2142 | Val Dice: 0.7743
#   -> Best model saved (epoch 30, val_dice=0.7743)
# Epoch 031 | Train Loss: 0.2239 | Train Dice: 0.7347 | Val Loss: 0.2143 | Val Dice: 0.7857
#   -> Best model saved (epoch 31, val_dice=0.7857)
# Epoch 032 | Train Loss: 0.2237 | Train Dice: 0.7230 | Val Loss: 0.2193 | Val Dice: 0.6767
# Epoch 033 | Train Loss: 0.2228 | Train Dice: 0.7310 | Val Loss: 0.2221 | Val Dice: 0.7335
# Epoch 034 | Train Loss: 0.2235 | Train Dice: 0.7154 | Val Loss: 0.2201 | Val Dice: 0.7131
# Epoch 035 | Train Loss: 0.2205 | Train Dice: 0.7324 | Val Loss: 0.2144 | Val Dice: 0.7671
# Epoch 036 | Train Loss: 0.2214 | Train Dice: 0.7180 | Val Loss: 0.2142 | Val Dice: 0.6836
# Epoch 037 | Train Loss: 0.2188 | Train Dice: 0.7262 | Val Loss: 0.2122 | Val Dice: 0.7896
#   -> Best model saved (epoch 37, val_dice=0.7896)
# Epoch 038 | Train Loss: 0.2178 | Train Dice: 0.7315 | Val Loss: 0.2089 | Val Dice: 0.7600
# Epoch 039 | Train Loss: 0.2221 | Train Dice: 0.7178 | Val Loss: 0.2189 | Val Dice: 0.7487
# Epoch 040 | Train Loss: 0.2146 | Train Dice: 0.7344 | Val Loss: 0.2142 | Val Dice: 0.7101
# Epoch 041 | Train Loss: 0.2159 | Train Dice: 0.7372 | Val Loss: 0.2175 | Val Dice: 0.6987
# Epoch 042 | Train Loss: 0.2159 | Train Dice: 0.7387 | Val Loss: 0.2082 | Val Dice: 0.7618
# Epoch 043 | Train Loss: 0.2149 | Train Dice: 0.7459 | Val Loss: 0.2135 | Val Dice: 0.7253
# Epoch 044 | Train Loss: 0.2141 | Train Dice: 0.7368 | Val Loss: 0.2144 | Val Dice: 0.7819
# Epoch 045 | Train Loss: 0.2146 | Train Dice: 0.7479 | Val Loss: 0.2027 | Val Dice: 0.7627
# Epoch 046 | Train Loss: 0.2088 | Train Dice: 0.7729 | Val Loss: 0.2034 | Val Dice: 0.7736
# Epoch 047 | Train Loss: 0.2155 | Train Dice: 0.7365 | Val Loss: 0.2029 | Val Dice: 0.7746
# Epoch 048 | Train Loss: 0.2090 | Train Dice: 0.7536 | Val Loss: 0.2183 | Val Dice: 0.6839
# Epoch 049 | Train Loss: 0.2102 | Train Dice: 0.7454 | Val Loss: 0.2073 | Val Dice: 0.7663
# Epoch 050 | Train Loss: 0.2078 | Train Dice: 0.7674 | Val Loss: 0.2127 | Val Dice: 0.7000
# Epoch 051 | Train Loss: 0.2065 | Train Dice: 0.7532 | Val Loss: 0.2015 | Val Dice: 0.7760
# Epoch 052 | Train Loss: 0.2045 | Train Dice: 0.7673 | Val Loss: 0.2098 | Val Dice: 0.7767
# Epoch 053 | Train Loss: 0.2122 | Train Dice: 0.7604 | Val Loss: 0.2031 | Val Dice: 0.7876
# Epoch 054 | Train Loss: 0.2074 | Train Dice: 0.7655 | Val Loss: 0.2179 | Val Dice: 0.7048
# Epoch 055 | Train Loss: 0.2051 | Train Dice: 0.7545 | Val Loss: 0.2073 | Val Dice: 0.7183
# Epoch 056 | Train Loss: 0.2067 | Train Dice: 0.7593 | Val Loss: 0.2190 | Val Dice: 0.6756
# Epoch 057 | Train Loss: 0.2101 | Train Dice: 0.7519 | Val Loss: 0.2102 | Val Dice: 0.7912
#   -> Best model saved (epoch 57, val_dice=0.7912)
# Epoch 058 | Train Loss: 0.2018 | Train Dice: 0.7930 | Val Loss: 0.2019 | Val Dice: 0.8220
#   -> Best model saved (epoch 58, val_dice=0.8220)
# Epoch 059 | Train Loss: 0.2049 | Train Dice: 0.7586 | Val Loss: 0.2031 | Val Dice: 0.7172
# Epoch 060 | Train Loss: 0.2043 | Train Dice: 0.7690 | Val Loss: 0.2068 | Val Dice: 0.7083
# Epoch 061 | Train Loss: 0.2006 | Train Dice: 0.7759 | Val Loss: 0.1975 | Val Dice: 0.8315
#   -> Best model saved (epoch 61, val_dice=0.8315)
# Epoch 062 | Train Loss: 0.2005 | Train Dice: 0.7850 | Val Loss: 0.2000 | Val Dice: 0.7999
# Epoch 063 | Train Loss: 0.2045 | Train Dice: 0.7422 | Val Loss: 0.2000 | Val Dice: 0.7632
# Epoch 064 | Train Loss: 0.2001 | Train Dice: 0.7851 | Val Loss: 0.2057 | Val Dice: 0.7529
# Epoch 065 | Train Loss: 0.1999 | Train Dice: 0.7770 | Val Loss: 0.2012 | Val Dice: 0.7236
# Epoch 066 | Train Loss: 0.2017 | Train Dice: 0.7623 | Val Loss: 0.1988 | Val Dice: 0.8027
# Epoch 067 | Train Loss: 0.1977 | Train Dice: 0.7812 | Val Loss: 0.2040 | Val Dice: 0.8250
# Epoch 068 | Train Loss: 0.2009 | Train Dice: 0.7739 | Val Loss: 0.2043 | Val Dice: 0.7627
# Epoch 069 | Train Loss: 0.1953 | Train Dice: 0.7784 | Val Loss: 0.2048 | Val Dice: 0.8303
# Epoch 070 | Train Loss: 0.1978 | Train Dice: 0.7751 | Val Loss: 0.2233 | Val Dice: 0.6696
# Epoch 071 | Train Loss: 0.1945 | Train Dice: 0.8040 | Val Loss: 0.1973 | Val Dice: 0.8304
# Epoch 072 | Train Loss: 0.2006 | Train Dice: 0.7433 | Val Loss: 0.1988 | Val Dice: 0.7900
# Epoch 073 | Train Loss: 0.1985 | Train Dice: 0.7694 | Val Loss: 0.1975 | Val Dice: 0.7958
# Epoch 074 | Train Loss: 0.1960 | Train Dice: 0.7864 | Val Loss: 0.1981 | Val Dice: 0.7007
# Epoch 075 | Train Loss: 0.1943 | Train Dice: 0.7938 | Val Loss: 0.1992 | Val Dice: 0.8054
# Epoch 076 | Train Loss: 0.1928 | Train Dice: 0.7969 | Val Loss: 0.1989 | Val Dice: 0.8299
# Epoch 077 | Train Loss: 0.1991 | Train Dice: 0.7650 | Val Loss: 0.1941 | Val Dice: 0.7877
# Epoch 078 | Train Loss: 0.1936 | Train Dice: 0.7956 | Val Loss: 0.1950 | Val Dice: 0.7587
# Epoch 079 | Train Loss: 0.1960 | Train Dice: 0.7747 | Val Loss: 0.2043 | Val Dice: 0.8248
# Epoch 080 | Train Loss: 0.1946 | Train Dice: 0.7983 | Val Loss: 0.1940 | Val Dice: 0.7796
# Epoch 081 | Train Loss: 0.1977 | Train Dice: 0.7842 | Val Loss: 0.1944 | Val Dice: 0.8224
# Epoch 082 | Train Loss: 0.1933 | Train Dice: 0.8018 | Val Loss: 0.1949 | Val Dice: 0.8031
# Epoch 083 | Train Loss: 0.1941 | Train Dice: 0.8014 | Val Loss: 0.1949 | Val Dice: 0.8031
# Epoch 084 | Train Loss: 0.1946 | Train Dice: 0.7814 | Val Loss: 0.2071 | Val Dice: 0.7742
# Epoch 085 | Train Loss: 0.1908 | Train Dice: 0.8021 | Val Loss: 0.1921 | Val Dice: 0.7852
# Epoch 086 | Train Loss: 0.1936 | Train Dice: 0.7994 | Val Loss: 0.1943 | Val Dice: 0.8474
#   -> Best model saved (epoch 86, val_dice=0.8474)
# Epoch 087 | Train Loss: 0.1924 | Train Dice: 0.8030 | Val Loss: 0.1925 | Val Dice: 0.8062
# Epoch 088 | Train Loss: 0.1991 | Train Dice: 0.7885 | Val Loss: 0.1947 | Val Dice: 0.7448
# Epoch 089 | Train Loss: 0.1902 | Train Dice: 0.7986 | Val Loss: 0.1990 | Val Dice: 0.7949
# Epoch 090 | Train Loss: 0.1904 | Train Dice: 0.7885 | Val Loss: 0.1957 | Val Dice: 0.7348
# Epoch 091 | Train Loss: 0.1891 | Train Dice: 0.8206 | Val Loss: 0.1981 | Val Dice: 0.8090
# Epoch 092 | Train Loss: 0.1938 | Train Dice: 0.7865 | Val Loss: 0.2030 | Val Dice: 0.8471
# Epoch 093 | Train Loss: 0.1923 | Train Dice: 0.8141 | Val Loss: 0.1971 | Val Dice: 0.7647
# Epoch 094 | Train Loss: 0.1876 | Train Dice: 0.8289 | Val Loss: 0.1983 | Val Dice: 0.8188
# Epoch 095 | Train Loss: 0.1906 | Train Dice: 0.8127 | Val Loss: 0.1974 | Val Dice: 0.8102
# Epoch 096 | Train Loss: 0.1911 | Train Dice: 0.8038 | Val Loss: 0.1988 | Val Dice: 0.8378
# Epoch 097 | Train Loss: 0.1873 | Train Dice: 0.8073 | Val Loss: 0.1955 | Val Dice: 0.7300
# Epoch 098 | Train Loss: 0.1912 | Train Dice: 0.7929 | Val Loss: 0.1975 | Val Dice: 0.8184
# Epoch 099 | Train Loss: 0.1866 | Train Dice: 0.8213 | Val Loss: 0.1895 | Val Dice: 0.8248
# Epoch 100 | Train Loss: 0.1899 | Train Dice: 0.8273 | Val Loss: 0.1986 | Val Dice: 0.8548
#   -> Best model saved (epoch 100, val_dice=0.8548)

# %%
from dataloader import MultiTaskBrainDataset
import os 

test_data = MultiTaskBrainDataset(
    os.path.join("..", "brisc2025"),
    mode="segmentation",
    train_or_test="test",
    augment=False,
    seed=42,
    new_height=256,
    new_width=256
)

test_loader = DataLoader(test_data, batch_size=4, shuffle=False, num_workers=0)

# Load best checkpoint
checkpoint_dir  = os.path.join("..", "results", "segmentation", "tumor_segmentation_v2.1_grant")
best_model_path = os.path.join(checkpoint_dir, "best_model.pt")

loss_fn   = DiceBCELoss(bce_weight=0.5, dice_weight=0.5)

checkpoint = torch.load(best_model_path, map_location=device)
model = TinyUNet(num_classes=1, base_ch=12)
model.load_state_dict(checkpoint["model_state_dict"])
model.to(device)

print(f"Loaded best model from epoch {checkpoint['epoch']} "
      f"(val_dice={checkpoint['val_dice']:.4f})")

def dice_coefficient(pred_logits, target, threshold=0.5, eps=1e-6):
    """
    Computes the Dice score between predicted binary mask and ground truth.
    pred_logits: raw model output (B, 1, H, W)
    target:      ground truth mask (B, 1, H, W), values in {0, 1}
    """
    probs = torch.sigmoid(pred_logits)
    preds = (probs > threshold).float()
    intersection = (preds * target).sum(dim=(1, 2, 3))
    union = preds.sum(dim=(1, 2, 3)) + target.sum(dim=(1, 2, 3))
    dice = (2.0 * intersection + eps) / (union + eps)
    return dice.mean().item()

model.eval()

test_loss = 0.0
test_dice = 0.0
all_preds = []
all_masks = []

with torch.no_grad():
    for inputs, masks in test_loader:
        inputs, masks = inputs.to(device), masks.to(device)
        predictions = model(inputs)
        loss = loss_fn(predictions, masks.float())

        test_loss += loss.item()
        test_dice += dice_coefficient(predictions, masks)

        binary_preds = (torch.sigmoid(predictions) > 0.5).float().cpu()
        all_preds.append(binary_preds)
        all_masks.append(masks.cpu())

test_loss /= len(test_loader)
test_dice /= len(test_loader)

print(f"\nTest Loss: {test_loss:.4f} | Test Dice: {test_dice:.4f}")

from sklearn.metrics import precision_score, recall_score, f1_score

all_preds_flat = torch.cat(all_preds).view(-1).numpy().astype(int)
all_masks_flat = torch.cat(all_masks).view(-1).numpy().astype(int)

precision = precision_score(all_masks_flat, all_preds_flat, zero_division=0)
recall    = recall_score   (all_masks_flat, all_preds_flat, zero_division=0)
f1        = f1_score       (all_masks_flat, all_preds_flat, zero_division=0)

print(f"Pixel Precision : {precision:.4f}")
print(f"Pixel Recall    : {recall:.4f}")
print(f"Pixel F1 Score  : {f1:.4f}")
# Out:
# C:\Users\glawl\AppData\Local\Temp\ipykernel_24476\812295583.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(best_model_path, map_location=device)
# Loaded best model from epoch 100 (val_dice=0.8548)
#
# Test Loss: 0.1852 | Test Dice: 0.8504
# Pixel Precision : 0.8325
# Pixel Recall    : 0.8881
# Pixel F1 Score  : 0.8594
